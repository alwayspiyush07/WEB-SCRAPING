# %% [markdown]
# ***GET REQUESTS***

# %%
import requests

# %%
web = requests.get("https://www.coursera.org/")
print(web)
# Out:
# <Response [200]>

# %%
web.content 
#to view the code of website
# Out:
# b'<!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org" lang="en" dir="ltr" data-color-theme="{{{colorTheme}}}"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin><link rel="preconnect" href="https://browser.sentry-cdn.com" crossorigin><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="viewport" content="width=device-width, initial-
# ...

# %%
web.status_code
#to view the response
# Out:
# 200

# %% [markdown]
# ***Parsing the HTML in web page using python***

# %%
import requests 
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.coursera.org/")

# %%
web.status_code
# Out:
# 200

# %%
web.content
# Out:
# b'<!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org" lang="en" dir="ltr" data-color-theme="{{{colorTheme}}}"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin><link rel="preconnect" href="https://browser.sentry-cdn.com" crossorigin><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="viewport" content="width=device-width, initial-
# ...

# %%
#to get the formatted HTML code 
soup = BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-color-theme="{{{colorTheme}}}" dir="ltr" itemtype="http://schema.org" lang="en" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <link crossorigin="" href="https://d3njjcbhbojbot.cloudfront.net" rel="preconnect"/>
#   <link crossorigin="" href="https://browser.sentry-cdn.com" rel="preconnect"/>
#   <meta content="IE=Edge,chrome=IE7" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="Coursera" property="og:site_name"/>
#   <meta content="727836538,4807654" property="fb:admins"/>
#   <meta content="823425307723964" property="fb:app_id"/>
#   <meta content="Coursera" name="twitter:site"/>
#   <meta content="Coursera" name="twitter:app:name:iphone"/>
#   <meta content="Coursera" name="twitter:app:name:ipad"/>
#   <meta content="Coursera" name="twitter:app:name:googleplay"/>
#   <meta content="id736535961" name="twitter:app:id:iphone"/>
#   <meta content="id736535961" name="twitter:app:id:ipad"/>
# ...

# %%
soup.title
# to retrieve the data under the title tag
# Out:
# <title data-react-helmet="true">Coursera | Courses, Professional Certificates, and Degrees Online</title>

# %%
#first paragragh tag
soup.p
# Out:
# <p class="css-1rcwhif">It’s a brilliant time to begin with 10,000+ programs for ₹6,999/year. Price goes up 18 June.</p>

# %%
#first anchor tag
soup.a
# Out:
# <a aria-current="page" class="cds-119 cds-113 cds-115 css-12x0a78 cds-142" data-click-key="front_page.front_page_story.click.navigation_meta_nav_Individuals" data-click-value='{"href":"https://www.coursera.org/","namespace":{"action":"click","app":"front_page","component":"navigation_meta_nav_Individuals","page":"front_page_story"},"schema_type":"FRONTEND"}' data-track="true" data-track-action="click" data-track-app="front_page" data-track-component="navigation_meta_nav_Individuals" data-track-href="https://www.coursera.org/" data-track-page="front_page_story" href="https://www.coursera.org/" to="https://www.coursera.org/"><span><span class="forStyle css-1rkctw9">For</span> Individuals</span></a>

# %%
#first header tag
soup.h1
# Out:
# <h1 class="rc-A11yScreenReaderOnly css-1whdyhf" data-testid="visually-hidden">Learn without limits</h1>

# %% [markdown]
# ***NavigableString***

# %%
soup.p.string
# Out:
# 'It’s a brilliant time to begin with 10,000+ programs for ₹6,999/year. Price goes up 18 June.'

# %%
soup.a.string

# %%
soup.h1.string
# Out:
# 'Learn without limits'

# %% [markdown]
# ***BeautifulSoup***

# %%
soup.find("p")
# Out:
# <p class="css-1rcwhif">It’s a brilliant time to begin with 10,000+ programs for ₹6,999/year. Price goes up 18 June.</p>

# %%
soup.find_all("p")
# Out:
# [<p class="css-1rcwhif">It’s a brilliant time to begin with 10,000+ programs for ₹6,999/year. Price goes up 18 June.</p>,
#  <p class="css-1rcwhif">Get 50% off team training you can start today. Begin now before prices go up June 18.</p>,
#  <p class="css-1rcwhif">Pracitical knowledge from OpenAI, Anthropic, Google, and more is here for your career path. </p>,
#  <p>No prior experience needed to get started.</p>,
#  <p>Explore multiple career pathways with entry-level programs from Google. <a class="cds-119 cds-113 cds-115 css-56pmb3 cds-142" href="https://www.coursera.org/google-career-certificates">Learn more</a></p>,
#  <p>Develop the real-world skills you need to shine in today’s AI engineering roles. <a class="cds-119 cds-113 cds-115 css-56pmb3 cds-142" href="https://www.coursera.org/explore/ai-engineering">Learn more</a></p>,
#  <p class="css-5fnvki">Start my career</p>,
#  <p class="css-5fnvki">Change my career</p>,
#  <p class="css-5fnvki">Grow in my current role</p>,
# ...

# %% [markdown]
# ***Extracting text from tags in web page using python***

# %%
import requests 
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.coursera.org/")
s = web.content
s
# Out:
# b'<!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org" lang="en" dir="ltr" data-color-theme="{{{colorTheme}}}"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin><link rel="preconnect" href="https://browser.sentry-cdn.com" crossorigin><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="viewport" content="width=device-width, initial-
# ...

# %%
soup = BeautifulSoup(s,'html.parser')

# %%
lines = soup.find_all("p")
lines
# Out:
# [<p class="css-1rcwhif">It’s a brilliant time to begin with 10,000+ programs for ₹6,999/year. Price goes up 18 June.</p>,
#  <p class="css-1rcwhif">Get 50% off team training you can start today. Begin now before prices go up June 18.</p>,
#  <p class="css-1rcwhif">Pracitical knowledge from OpenAI, Anthropic, Google, and more is here for your career path. </p>,
#  <p>No prior experience needed to get started.</p>,
#  <p>Explore multiple career pathways with entry-level programs from Google. <a class="cds-119 cds-113 cds-115 css-56pmb3 cds-142" href="https://www.coursera.org/google-career-certificates">Learn more</a></p>,
#  <p>Develop the real-world skills you need to shine in today’s AI engineering roles. <a class="cds-119 cds-113 cds-115 css-56pmb3 cds-142" href="https://www.coursera.org/explore/ai-engineering">Learn more</a></p>,
#  <p class="css-5fnvki">Start my career</p>,
#  <p class="css-5fnvki">Change my career</p>,
#  <p class="css-5fnvki">Grow in my current role</p>,
# ...

# %%
for l in lines:
    print(l.text)
# Out:
# It’s a brilliant time to begin with 10,000+ programs for ₹6,999/year. Price goes up 18 June.
# Get 50% off team training you can start today. Begin now before prices go up June 18.
# Pracitical knowledge from OpenAI, Anthropic, Google, and more is here for your career path.
# No prior experience needed to get started.
# Explore multiple career pathways with entry-level programs from Google. Learn more
# Develop the real-world skills you need to shine in today’s AI engineering roles. Learn more
# Start my career
# Change my career
# Grow in my current role
# Explore topics outside of work
# ...

# %% [markdown]
# ***Extracting links from a web page using python***

# %%
import requests
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.coursera.org/")

# %%
soup = BeautifulSoup(web.content,"html.parser")

# %%
soup.find_all("a")
# Out:
# [<a aria-current="page" class="cds-119 cds-113 cds-115 css-12x0a78 cds-142" data-click-key="front_page.front_page_story.click.navigation_meta_nav_Individuals" data-click-value='{"href":"https://www.coursera.org/","namespace":{"action":"click","app":"front_page","component":"navigation_meta_nav_Individuals","page":"front_page_story"},"schema_type":"FRONTEND"}' data-track="true" data-track-action="click" data-track-app="front_page" data-track-component="navigation_meta_nav_Individuals" data-track-href="https://www.coursera.org/" data-track-page="front_page_story" href="https://www.coursera.org/" to="https://www.coursera.org/"><span><span class="forStyle css-1rkctw9">For</span> Individuals</span></a>,
# ...

# %%
for i in soup.find_all("a"):
    print(i.get("href"))
# Out:
# https://www.coursera.org/
# https://www.coursera.org/business?utm_content=corp-to-home-for-enterprise&utm_campaign=website&utm_medium=coursera&utm_source=header&utm_term=b-out
# https://www.coursera.org/campus?utm_content=corp-to-landing-for-campus&utm_campaign=website&utm_medium=coursera&utm_source=header&utm_term=b-out
# https://www.coursera.org/government?utm_content=corp-to-landing-for-government&utm_campaign=website&utm_medium=coursera&utm_source=header&utm_term=b-out
# /
# /degrees
# /?authMode=login
# /?authMode=signup
# /
# https://www.coursera.org/courseraplus/special/cplus-annual-june-2026-india
# https://www.coursera.org/business/teams?promoCode=summer50-2026&utm_medium=coursera&utm_source=home-page&utm_campaign=summer50-2026&utm_content=hero-cta
# https://www.coursera.org/?authMode=signup
# /explore/most-popular-courses
# /explore/new-on-coursera
# /browse
# ...

# %% [markdown]
# ***Extracting images from a web page using python***

# %%
import requests 
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.coursera.org/")

# %%
soup = BeautifulSoup(web.content,"html.parser")

# %%
img = soup.find_all("img")
img
# Out:
# [<img alt="Coursera Plus logo" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/00atxywtfxvd/7rJLBhLIFG5ZTss6mYJ2vj/6040ccb86b45a0f0deb1a16d1f42b35c/courseraplus-blue.png?auto=format%2Ccompress&amp;dpr=1&amp;w=470&amp;h=16" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/00atxywtfxvd/7rJLBhLIFG5ZTss6mYJ2vj/6040ccb86b45a0f0deb1a16d1f42b35c/courseraplus-blue.png?auto=format%2Ccompress&amp;dpr=2&amp;w=470&amp;h=16 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/00atxywtfxvd/7rJLBhLIFG5ZTss6mYJ2vj/6040ccb86b45a0f0deb1a16d1f42b35c/courseraplus-blue.png?auto=format%2Ccompress&amp;dpr=3&amp;w=470&amp;h=16 3x" style="max-width:100%;max-height:16px;height:auto;border-radius:0"/>,
# ...

# %%
for i in img:
    print(i.get("src"))
# Out:
# https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/00atxywtfxvd/7rJLBhLIFG5ZTss6mYJ2vj/6040ccb86b45a0f0deb1a16d1f42b35c/courseraplus-blue.png?auto=format%2Ccompress&dpr=1&w=470&h=16
# https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/00atxywtfxvd/3pQqaXxUPawYhaR6RcCHBj/4b04439c9b2905928b6369140c5520fb/India_Early_Bird-Ends_soon_LOHP-Desktop_330x304.png?auto=format%2C%20compress&dpr=1&w=323&q=40&fit=clip
# https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/00atxywtfxvd/3OYpxt8mmtxQGEyCZ76oqE/6e4a82d152d8f0dbe770bc0507655853/WES_Coursera_for_Teams_Logo__1_.png?auto=format%2Ccompress&dpr=1&w=1614&h=18
# ...
